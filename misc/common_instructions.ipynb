# %%
asm_6502 = ["ADC", "AND", "ASL", "BCC", "BCS", "BEQ", "BIT", "BMI", "BNE", "BPL", "BRK", "BVC", "BVS", "CLC", "CLD", "CLI", "CLV", "CMP", "CPX", "CPY", "DEC", "DEX", "DEY", "EOR", "INC", "INX", "INY", "JMP", "JSR", "LDA", "LDX", "LDY", "LSR", "NOP", "ORA", "PHA", "PHP", "PLA", "PLP", "ROL", "ROR", "RTI", "RTS", "SBC", "SEC", "SED", "SEI", "STA", "STX", "STY", "TAX", "TAY", "TSX", "TXA", "TXS", "TYA"]
asm_arm = ["ADC", "ADD", "AND", "B", "BIC", "BKPT", "BL", "BLX", "BX", "CDP", "CDP2", "CLZ", "CMN", "CMP", "EOR", "LDC", "LDC2", "LDM", "LDR", "MAR", "MCR", "MCR2", "MCRR", "MIA", "MIAPH", "MIAxy", "MLA", "MOV", "MRA", "MRC", "MRC2", "MRRC", "MRS", "MSR", "MUL", "MVN", "ORR", "PLD", "QADD", "QDADD", "QDSUB", "QSUB", "RSB", "RSC", "SBC", "SMLAL", "SMLALxy", "SMLAWy", "SMLAxy", "SMULL", "SMULWy", "SMULxy", "STC", "STC2", "STM", "STR", "SUB", "SWI", "SWP", "TEQ", "TST", "UMLAL", "UMULL", "EQ", "NE", "CS", "HS", "CC", "LO", "MI", "PL", "VS", "VC", "HI", "LS", "GE", "LT", "GT", "LE", "AL"]
asm_x86 = ["AAA", "AAD", "AAM", "AAS", "ADC", "ADD", "ADSIZE", "ARPL", "BOUND", "CALL", "CBW", "CLC", "CLD", "CLI", "CMC", "CMP", "CMPSB", "CMPSW", "CS", "CWD", "DAA", "DAS", "DEC", "DS", "ENTER", "ES", "ESC", "FS", "GS", "HLT", "IMUL", "IN", "INC", "INSB", "INSW", "INT", "INT1", "INT3", "INTO", "IRET", "JA", "JB", "JBE", "JCXZ", "JL", "JLE", "JMP", "JNB", "JNL", "JNLE", "JNO", "JNP", "JNS", "JNZ", "JO", "JP", "JS", "JZ", "LAHF", "LDS", "LEA", "LEAVE", "LES", "LOCK", "LODSB", "LODSW", "LOOP", "LOOPNZ", "LOOPZ", "MOV", "MOVSB", "MOVSW", "NOP", "OPSIZE", "OR", "OUT", "OUTSB", "OUTSW", "POP", "POPA", "POPF", "PUSH", "PUSHA", "PUSHF", "REP", "REPNE", "RETF", "RETN", "SAHF", "SALC", "SBB", "SCASB", "SCASW", "SS", "STC", "STD", "STI", "STOSB", "STOSW", "SUB", "TEST", "TWOBYTE", "WAIT", "XCHG", "XLAT", "XOR"]
asm_8080 = ["ACI", "ADC", "ADD", "ADI", "ANA", "ANI", "CALL", "CC", "CM", "CMA", "CMC", "CMP", "CNC", "CNZ", "CP", "CPE", "CPI", "CPO", "CZ", "DAA", "DAD", "DCR", "DCX", "DI", "EI", "HLT", "IN", "INR", "INX", "JC", "JM", "JMP", "JNC", "JNZ", "JP", "JPE", "JPO", "JZ", "LDA", "LDAX", "LHLD", "LXI", "MOV", "MVI", "NOP", "ORA", "ORI", "OUT", "PCHL", "POP", "PUSH", "RAL", "RAR", "RC", "RET", "RLC", "RM", "RNC", "RNZ", "RP", "RPE", "RPO", "RRC", "RST", "RZ", "SBB", "SBI", "SHLD", "SPHL", "STA", "STAX", "STC", "SUB", "SUI", "XCHG", "XRA", "XRI", "XTHL"]
asm_mips = ["abs", "add", "addi", "addiu", "addu", "and", "andi", "beq", "bgtz", "blez", "bne", "div", "divu", "j", "jal", "jalr", "jr", "lb", "lbu", "lh", "lhu", "lui", "lw", "mfhi", "mflo", "mthi", "mtlo", "mult", "multu", "nor", "or", "ori", "sb", "sh", "sll", "sllv", "slt", "slti", "sltiu", "sltu", "sra", "srav", "srl", "srlv", "sub", "subu", "sw", "syscall", "xor", "xori"]
asm_riscv = ["ADD", "ADDI", "ADDIW", "ADDW", "AND", "ANDI", "AUIPC", "BEQ", "BGE", "BGEU", "BLT", "BLTU", "BNE", "DIV", "DIVU", "DIVUW", "DIVW", "FENCE", "FENCE.I", "JAL", "JALR", "LB", "LBU", "LD", "LH", "LHU", "LUI", "LW", "LWU", "MUL", "MULH", "MULHSU", "MULHU", "MULW", "OR", "ORI", "REM", "REMU", "REMUW", "REMW", "SB", "SD", "SH", "SLL", "SLLI", "SLLIW", "SLLW", "SLT", "SLTI", "SLTIU", "SLTU", "SRA", "SRAI", "SRAIW", "SRAW", "SRL", "SRLI", "SRLIW", "SRLW", "SUB", "SUBW", "SW", "XOR", "XORI"]

# %%
d = dict()
for instruction in asm_6502 + asm_arm + asm_x86 + asm_8080 + asm_mips + asm_riscv:
    instruction = instruction.lower()
    d[instruction] = d.get(instruction, 0) + 1

# %%
sorted(d.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('add', 5),
#  ('sub', 5),
#  ('adc', 4),
#  ('and', 4),
#  ('cmp', 4),
#  ('beq', 3),
#  ('bne', 3),
#  ('jmp', 3),
#  ('nop', 3),
#  ('mov', 3),
#  ('stc', 3),
#  ('or', 3),
#  ('xor', 3),
#  ('ori', 3),
#  ('clc', 2),
#  ('cld', 2),
#  ('cli', 2),
#  ('dec', 2),
#  ('eor', 2),
#  ('inc', 2),
#  ('inx', 2),
#  ('lda', 2),
#  ('ora', 2),
#  ('sbc', 2),
#  ('sta', 2),
#  ('mul', 2),
#  ('cs', 2),
#  ('cc', 2),
#  ('call', 2),
#  ('cmc', 2),
#  ('daa', 2),
#  ('hlt', 2),
#  ('in', 2),
#  ('jnz', 2),
#  ('jp', 2),
#  ('jz', 2),
#  ('out', 2),
#  ('pop', 2),
#  ('push', 2),
#  ('sbb', 2),
#  ('xchg', 2),
#  ('addi', 2),
#  ('andi', 2),
#  ('div', 2),
#  ('divu', 2),
#  ('jal', 2),
#  ('jalr', 2),
#  ('lb', 2),
#  ('lbu', 2),
#  ('lh', 2),
#  ('lhu', 2),
#  ('lui', 2),
#  ('lw', 2),
#  ('sb', 2),
#  ('sh', 2),
#  ('sll', 2),
#  ('slt', 2),
#  ('slti', 2),
#  ('sltiu', 2),
#  ('sltu', 2),
#  ('sra', 2),
#  ('srl', 2),
#  ('sw', 2),
#  ('xori', 2),
#  ('asl', 1),
#  ('bcc', 1),
# ...
